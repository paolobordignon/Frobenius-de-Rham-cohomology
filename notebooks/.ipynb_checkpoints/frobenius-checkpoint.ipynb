# %% [markdown]
# ## Frobenius action on de Rham cohomology of Elliptic Curves
#
# The following notebook contains the necessary steps to compute the Frobenius action on $H_{dR}$

# %%
p = 5
Z5 = Zp(p, prec = 10, type = 'capped-abs', print_mode = 'series')
R.<x> = PowerSeriesRing(Z5)
S.<z> = PowerSeriesRing(R,default_prec=5*20)

# %%
E = EllipticCurve([-1,0])
f = x^3+E.a4()*x+E.a6()
frob_x = x^p
#frob_y = y^p*(1+(f(x^p)-f(x)^p)*1/f(x)^p)^(1/2)
frob_z = z^p*(1+(f(x^p)-f(x)^p)*z^(2*p))^(-1/2)

# %% [markdown]
# We now consider the following differentials
# $$ \omega = \frac{dx}{y}=zdx$$
# $$\eta = \frac{xdx}{y}=zxdx$$
# and the action of the Frobenius morphism $\varphi$
# $$ \varphi^*(\omega) = px^{p-1}\varphi(z)dx$$
# $$ \varphi^*(\eta) = px^{2p-1}\varphi(z)dx$$

# %% [markdown]
# This is an andomorphism of the de Rham cohomology group $H_{dR}(E/\mathbb{Q}_5)$. In particular there exists a matrix $M$ and two rational functions $f_\omega,f_\eta$ such that the following holds
# $$ \begin{pmatrix}\varphi^*(\omega) \\ \varphi^*(\eta)\end{pmatrix} = M\cdot \begin{pmatrix}\omega \\ \eta \end{pmatrix} + \begin{pmatrix} df_\omega \\ df_\eta\end{pmatrix}$$

# %%
frob_omega = p*x^(p-1)*frob_z
frob_eta = p*x^(2*p-1)*frob_z
frob_eta
# Out:
# (O(5^10) + O(5^10)*x + O(5^10)*x^2 + O(5^10)*x^3 + O(5^10)*x^4 + O(5^10)*x^5 + O(5^10)*x^6 + O(5^10)*x^7 + O(5^10)*x^8 + (5 + O(5^10))*x^9)*z^5 + (O(5^20) + O(5^20)*x + O(5^20)*x^2 + O(5^20)*x^3 + O(5^20)*x^4 + O(5^20)*x^5 + O(5^20)*x^6 + O(5^11)*x^7 + O(5^11)*x^8 + O(5^11)*x^9 + O(5^11)*x^10 + O(5^11)*x^11 + O(5^11)*x^12 + O(5^11)*x^13 + O(5^11)*x^14 + O(5^11)*x^15 + (3*5^2 + 2*5^3 + 2*5^4 + 2*5^5 + 2*5^6 + 2*5^7 + 2*5^8 + 2*5^9 + 2*5^10 + O(5^11))*x^16 + O(5^11)*x^17 + (4*5^2 + 4*5^3 + 4*5^4 + 4*5^5 + 4*5^6 + 4*5^7 + 4*5^8 + 4*5^9 + 4*5^10 + O(5^11))*x^18 + O(5^11)*x^19 + (5^2 + O(5^11))*x^20 + O(5^11)*x^21 + (2*5^2 + 2*5^3 + 2*5^4 + 2*5^5 + 2*5^6 + 2*5^7 + 2*5^8 + 2*5^9 + 2*5^10 + O(5^11))*x^22 + O(5^11)*x^23 + O(5^11)*x^24)*z^15 + (O(5^30) + O(5^30)*x + O(5^30)*x^2 + O(5^30)*x^3 + O(5^30)*x^4 + O(5^30)*x^5 + O(5^30)*x^6 + O(5^21)*x^7 + O(5^21)*x^8 + O(5^21)*x^9 + O(5^21)*x^10 + O(5^21)*x^11 + O(5^21)*x^12 + O(5^21)*x^13 + O(5^12)*x^14 + O(5^12)*x^15 + O(5^12)*x^16 + O(5^12)*x^17 + O(5^12)*x^18 + O(5^12)*x^19 + O(5^12)*x^20 + O(5^12)*x^21 + O(5^12)*x^22 + (5^3 + 3*5^4 + 3*5^6 + 3*5^8 + 3*5^10 + O(5^12))*x^23 + O(5^12)*x^24 + (5^3 + 2*5^4 + 2*5^5 + 2*5^6 + 2*5^7 + 2*5^8 + 2*5^9 + 2*5^10 + 2*5^11 + O(5^12))*x^25 + O(5^12)*x^26 + (3*5^3 + O(5^12))*x^27 + O(5^12)*x^28 + (3*5^4 + 3*5^5 + 3*5^6 + 3*5^7 + 3*5^8 + 3*5^9 + 3*5^10 + 3*5^11 + O(5^12))*x^29 + O(5^12)*x^30 + (3*5^3 + O(5^12))*x^31 + O(5^12)*x^32 + (5^3 + 2*5^4 + 2*5^5 + 2*5^6 + 2*5^7 + 2*5^8 + 2*5^9 + 2*5^10 + 2*5^11 + O(5^12))*x^33 + O(5^12)*x^34 + (5^3 + 3*5^4 + 3*5^6 + 3*5^8 + 3*5^10 + O(5^12))*x^35 + O(5^12)*x^36 + O(5^12)*x^37 + O(5^21)*x^38 + O(5^21)*x^39)*z^25 + (O(5^40) + O(5^40)*x + O(5^40)*x^2 + O(5^40)*x^3 + O(5^40)*x^4 + O(5^40)*x^5 + O(5^40)*x^6 + O(5^31)*x^7 + O(5^31)*x^8 + O(5^31)*x^9 + O(5^31)*x^10 + O(5^31)*x^11 + O(5^31)*x^12 + O(5^31)*x^13 + O(5^22)*x^14 + O(5^22)*x^15 + O(5^22)*x^16 + O(5^22)*x^17 + O(5^22)*x^18 + O(5^22)*x^19 + O(5^22)*x^20 + O(5^14)*x^21 + O(5^14)*x^22 + O(5^13)*x^23 + O(5^13)*x^24 + O(5^13)*x^25 + O(5^13)*x^26 + O(5^13)*x^27 + O(5^13)*x^28 + O(5^13)*x^29 + (5^5 + 2*5^6 + 3*5^7 + 4*5^8 + 2*5^10 + 3*5^11 + 4*5^12 + O(5^13))*x^30 + O(5^13)*x^31 + (4*5^5 + 5^6 + 4*5^7 + 5^8 + 4*5^9 + 5^10 + 4*5^11 + 5^12 + O(5^13))*x^32 + O(5^13)*x^33 + (3*5^5 + 4*5^6 + 5^7 + 4*5^8 + 5^9 + 4*5^10 + 5^11 + 4*5^12 + O(5^13))*x^34 + O(5^13)*x^35 + (3*5^6 + 4*5^7 + 2*5^9 + 3*5^10 + 4*5^11 + O(5^13))*x^36 + O(5^13)*x^37 + (3*5^5 + O(5^13))*x^38 + O(5^13)*x^39 + (2*5^5 + 4*5^6 + 4*5^7 + 4*5^8 + 4*5^9 + 4*5^10 + 4*5^11 + 4*5^12 + O(5^13))*x^40 + O(5^13)*x^41 + (2*5^6 + 4*5^8 + 2*5^9 + 5^10 + 4*5^12 + O(5^13))*x^42 + O(5^13)*x^43 + (2*5^5 + 3*5^7 + 3*5^9 + 3*5^11 + O(5^13))*x^44 + O(5^13)*x^45 + (5^5 + 3*5^6 + 3*5^8 + 3*5^10 + 3*5^12 + O(5^13))*x^46 + O(5^13)*x^47 + (4*5^5 + 2*5^6 + 5^7 + 4*5^9 + 2*5^10 + 5^11 + O(5^13))*x^48 + O(5^13)*x^49 + O(5^13)*x^50 + O(5^22)*x^51 + O(5^22)*x^52 + O(5^31)*x^53 + O(5^31)*x^54)*z^35 + (O(5^50) + O(5^50)*x + O(5^50)*x^2 + O(5^50)*x^3 + O(5^50)*x^4 + O(5^50)*x^5 + O(5^50)*x^6 + O(5^41)*x^7 + O(5^41)*x^8 + O(5^41)*x^9 + O(5^41)*x^10 + O(5^41)*x^11 + O(5^41)*x^12 + O(5^41)*x^13 + O(5^32)*x^14 + O(5^32)*x^15 + O(5^32)*x^16 + O(5^32)*x^17 + O(5^32)*x^18 + O(5^32)*x^19 + O(5^32)*x^20 + O(5^23)*x^21 + O(5^23)*x^22 + O(5^23)*x^23 + O(5^23)*x^24 + O(5^23)*x^25 + O(5^23)*x^26 + O(5^23)*x^27 + O(5^15)*x^28 + O(5^15)*x^29 + O(5^14)*x^30 + O(5^14)*x^31 + O(5^14)*x^32 + O(5^14)*x^33 + O(5^14)*x^34 + O(5^14)*x^35 + O(5^14)*x^36 + (4*5^6 + 3*5^7 + 5^8 + 2*5^10 + 4*5^11 + 4*5^12 + O(5^14))*x^37 + O(5^14)*x^38 + (3*5^6 + 4*5^7 + 2*5^9 + 3*5^10 + 4*5^11 + 2*5^13 + O(5^14))*x^39 + O(5^14)*x^40 + (3*5^6 + 5^7 + 5^8 + 5^9 + 5^10 + 5^11 + 5^12 + 5^13 + O(5^14))*x^41 + O(5^14)*x^42 + (4*5^6 + 2*5^8 + 5^10 + 4*5^11 + 4*5^12 + 2*5^13 + O(5^14))*x^43 + O(5^14)*x^44 + (3*5^7 + 5^8 + 5^9 + 5^10 + 5^11 + 5^12 + 5^13 + O(5^14))*x^45 + O(5^14)*x^46 + (2*5^6 + 3*5^7 + 5^8 + 3*5^9 + 4*5^10 + 2*5^12 + 3*5^13 + O(5^14))*x^47 + O(5^14)*x^48 + (3*5^6 + 5^8 + 2 ...

# %% [markdown]
# The following is a function to reduce the coefficient of the previous power series in the form
# $$ \sum_{i\in \mathbb{Z}}c_{i}z^{pi}$$
# with $c_i$ polynomials in $x$ of degree at most $2g+1$

# %%
V = LaurentSeriesRing(S)
def reduction_deg_2g(f,pol):
    """
    Given a polynomial in x, returns the representative in K[x,y,z]/(y^2-f(x),yz-1) that is a polynomial in K[x][z,z^(-1)] with the 
    degree in x <=2
    """
    if pol(z=1).degree()<3:
        return pol
    else: 
        n = pol(z=1).degree()
        pol += - pol(z=1).coefficients()[-1]*(f^(floor(n/3))-1/z^(2*floor(n/3)))*x^(n%3)
        return reduction_deg_2g(f,pol)

# %% [markdown]
# Test to check if algorithm for reduction of monomials work

# %%
V.<s,r,t> = PolynomialRing(QQ)
I = V.ideal(r^2-1-26*s-s^3,r*t-1)
I.reduce(s^22)
# Out:
# s*r^14 - 182*s^2*r^12 - 7*s*r^12 + 1092*s^2*r^10 + 14196*r^12 - 984235*s*r^10 + 31985590*s^2*r^8 - 85176*r^10 + 4921245*s*r^8 - 127949640*s^2*r^6 - 665144116*r^8 + 25939082659*s*r^6 - 288953239146*s^2*r^4 + 2661144304*r^6 - 77836933013*s*r^4 + 578162380484*s^2*r^2 + 1875451651788*r^4 - 54217194935481*s*r^2 + 140877982475178*s^2 - 3756225819320*r^2 + 54269088848831*s + 1878778238324

# %% [markdown]
# The following function takes a power series in $z$ and returns the corresponding power series where the coefficients are the $c_i$ above

# %%
def reduction_coeff(pow_ser):
    """
    Given a power series in z with coefficients polynomials in x, uses the function reduction_deg_2g() to return the power series
    with coefficients polynomials in x fo degree <3 in the polynomial ring K[x,y,z]/(y^2-f(x),yz-1)
    """
    pow_ser_2 = pow_ser
    for i in range(len(pow_ser_2.coefficients())):
        pow_ser += -z^pow_ser_2.exponents()[i]*pow_ser_2.coefficients()[i]+z^pow_ser_2.exponents()[i]*reduction_deg_2g(f,pow_ser_2.coefficients()[i])
    return pow_ser

# %% [markdown]
# Using the defining equation
# $$ \frac{1}{z^2}=y^2=f(x)$$
# we obtain the relation at the level of differentials given by
# $$ dz = -\frac{1}{2}z^3f'(x).$$
# From this we deduce
# $$ d(x^iz^j) = \left(ix^{i-1}z^j-\frac{1}{2}jf'(x)x^iz^{j+2}\right)dx$$
# The following function computes $d(x^iz^j)$ in the reduced form.

# %%
def differential_zn(f,i,n):
    """
    Compute the exact differential d(x^iz^n) with i=0,1,2 and n integer
    return p(x,z) where p(x,z)dx=d(x^i z^n) and p(x,z)=\sum p_i(x)z^i with degree(p_i(x))<3 
    """
    if n == 0:
        return i*x^(i-1)*z^0
    return (i*x^(i-1)*z^n+reduction_deg_2g(f,-1/2*n*f.derivative(x)*x^i)*z^(n+2))

# %% [markdown]
# In order to obtain the image of $\varphi^*(\omega)$ and $\varphi^*(\eta)$ in $H_{dR}$ we will need to understand what are the exact form $f_\omega, f_\eta$ for which
# $$ \begin{pmatrix}\varphi^*(\omega) \\ \varphi^*(\eta)\end{pmatrix} = M\cdot \begin{pmatrix}\omega \\ \eta \end{pmatrix} + \begin{pmatrix} df_\omega \\ df_\eta\end{pmatrix}.$$
# This computation reduces to a linear algebraic relation of the highest (for the positive part) and lowest (for the negative one) power of $z$ appearing in the expression $d(x^iz^j)$ previously computed.

# %%
def matrix_coeff_differentials_pos(n):
    matrix_diff = matrix(QQ,3)
    for i in range(3):
        if differential_zn(f,i,n) == 0:
            pol_coef = 0
        else:
            pol_coef = differential_zn(f,i,n).coefficients()[-1]
        for j in range(3):
            if pol_coef == 0:
                matrix_diff[j,i] = 0
            else:
                matrix_diff[j,i] = pol_coef[j]
    return matrix_diff

def matrix_coeff_differentials_neg(n):
    matrix_diff = matrix(QQ,3)
    for i in range(3):
        if differential_zn(f,i,n) == 0:
            pol_coef = 0
        else:
            if i == 0:
                pol_coef = differential_zn(f,i,n-2).coefficients()[0]
            else:
                pol_coef = differential_zn(f,i,n).coefficients()[0]
        for j in range(3):
            if pol_coef == 0:
                matrix_diff[j,i] = 0
            else:
                matrix_diff[j,i] = pol_coef[j]
    return matrix_diff

def vector_coeff(pol):
    return vector([pol[0],pol[1],pol[2]])

# %%
def reduction_z_pos(pow_ser,exact_form=0):
    if pow_ser.degree()<3:
        return (pow_ser,exact_form)
    else:
        k = pow_ser.degree()
        M = matrix_coeff_differentials_pos(k-2)
        V = vector_coeff(pow_ser.coefficients()[-1])
        X = M.solve_right(V)
        exact_form += X.dot_product(vector([x^0*z^(k-2),x^1*z^(k-2),x^2*z^(k-2)]))
        return reduction_z_pos(pow_ser-X.dot_product(vector([differential_zn(f,0,k-2),differential_zn(f,1,k-2),differential_zn(f,2,k-2)])),exact_form)

# %%
def reduction_z_neg(pow_ser,exact_form=0):
    if pow_ser.exponents()[0]>0:
        return (pow_ser,exact_form)
    else:
        k = pow_ser.exponents()[0]
        M = matrix_coeff_differentials_neg(k)
        V = vector_coeff(pow_ser.coefficients()[0])
        X = M.solve_right(V)
        exact_form += X.dot_product(vector([x^0*z^(k-2),x^1*z^k,x^2*z^k]))
        return reduction_z_neg(pow_ser-X.dot_product(vector([differential_zn(f,0,k-2),differential_zn(f,1,k),differential_zn(f,2,k)])),exact_form)

# %%
def reduction_z(pow_ser):
    red_pow_ser_pos, exact_pos = reduction_z_pos(pow_ser)
    red_pow_ser_neg, exact_neg = reduction_z_neg(red_pow_ser_pos,exact_pos)

    exact_form = exact_neg + red_pow_ser_neg[1][2]/(differential_zn(f,0,-1)[1][2])*z^(-1)
    red_pow_ser_fin = red_pow_ser_neg -red_pow_ser_neg[1][2]/(differential_zn(f,0,-1)[1][2])*differential_zn(f,0,-1)

    return (red_pow_ser_fin,exact_form)

# %%
def matrix_frobenius(p,f,prec=10, exact_dif = False):

    Z5 = Zp(p, prec, type = 'capped-abs', print_mode = 'series')
    
    frob_x = x^p
    #frob_y = y^p*(1+(f(x^p)-f(x)^p)*1/f(x)^p)^(1/2)
    frob_z = z^p*(1+(f(x^p)-f(x)^p)*z^(2*p))^(-1/2)

    frob_omega = p*x^(p-1)*frob_z
    frob_eta = p*x^(2*p-1)*frob_z
    
    red_frob_eta = reduction_coeff(frob_eta)
    red_frob_omega = reduction_coeff(frob_omega)

    red_frob_eta_fin, exact_form_eta= reduction_z(red_frob_eta)
    red_frob_omega_fin, exact_form_omega= reduction_z(red_frob_omega)

    matrix_frobenius = matrix(Z5,2)
    matrix_frobenius[0,0] = red_frob_omega_fin[1][0]
    matrix_frobenius[0,1] = red_frob_omega_fin[1][1]
    matrix_frobenius[1,0] = red_frob_eta_fin[1][0]
    matrix_frobenius[1,1] = red_frob_eta_fin[1][1]

    if exact_dif:
        return (matrix_frobenius, [exact_form_omega,exact_form_eta])
    else:
        return matrix_frobenius

f = x^3 - x^2
M = matrix_frobenius(5,f)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[95], line 30
#      27         return matrix_frobenius
#      29 f = x**Integer(3) - x**Integer(2)
# ---> 30 M = matrix_frobenius(Integer(5),f)
#
# Cell In[95], line 15, in matrix_frobenius(p, f, prec, exact_dif)
#      12 red_frob_eta = reduction_coeff(frob_eta)
#      13 red_frob_omega = reduction_coeff(frob_omega)
# ---> 15 red_frob_eta_fin, exact_form_eta= reduction_z(red_frob_eta)
#      16 red_frob_omega_fin, exact_form_omega= reduction_z(red_frob_omega)
#      18 matrix_frobenius = matrix(Z5,Integer(2))
#
# Cell In[94], line 2, in reduction_z(pow_ser)
#       1 def reduction_z(pow_ser):
# ----> 2     red_pow_ser_pos, exact_pos = reduction_z_pos(pow_ser)
#       3     red_pow_ser_neg, exact_neg = reduction_z_neg(red_pow_ser_pos,exact_pos)
#       5     exact_form = exact_neg + red_pow_ser_neg[Integer(1)][Integer(2)]/(differential_zn(f,Integer(0),-Integer(1))[Integer(1)][Integer(2)])*z**(-Integer(1))
#
# Cell In[76], line 10, in reduction_z_pos(pow_ser, exact_form)
#       8 X = M.solve_right(V)
#       9 exact_form += X.dot_product(vector([x**Integer(0)*z**(k-Integer(2)),x**Integer(1)*z**(k-Integer(2)),x**Integer(2)*z**(k-Integer(2))]))
# ---> 10 return reduction_z_pos(pow_ser-X.dot_product(vector([differential_zn(f,Integer(0),k-Integer(2)),differential_zn(f,Integer(1),k-Integer(2)),differential_zn(f,Integer(2),k-Integer(2))])),exact_form)
#
# Cell In[76], line 10, in reduction_z_pos(pow_ser, exact_form)
#       8 X = M.solve_right(V)
#       9 exact_form += X.dot_product(vector([x**Integer(0)*z**(k-Integer(2)),x**Integer(1)*z**(k-Integer(2)),x**Integer(2)*z**(k-Integer(2))]))
# ---> 10 return reduction_z_pos(pow_ser-X.dot_product(vector([differential_zn(f,Integer(0),k-Integer(2)),differential_zn(f,Integer(1),k-Integer(2)),differential_zn(f,Integer(2),k-Integer(2))])),exact_form)
#
#     [... skipping similar frames: reduction_z_pos at line 10 (2959 times)]
#
# Cell In[76], line 10, in reduction_z_pos(pow_ser, exact_form)
#       8 X = M.solve_right(V)
#       9 exact_form += X.dot_product(vector([x**Integer(0)*z**(k-Integer(2)),x**Integer(1)*z**(k-Integer(2)),x**Integer(2)*z**(k-Integer(2))]))
# ---> 10 return reduction_z_pos(pow_ser-X.dot_product(vector([differential_zn(f,Integer(0),k-Integer(2)),differential_zn(f,Integer(1),k-Integer(2)),differential_zn(f,Integer(2),k-Integer(2))])),exact_form)
#
# Cell In[76], line 6, in reduction_z_pos(pow_ser, exact_form)
#       4 else:
#       5     k = pow_ser.degree()
# ----> 6     M = matrix_coeff_differentials_pos(k-Integer(2))
#       7     V = vector_coeff(pow_ser.coefficients()[-Integer(1)])
#       8     X = M.solve_right(V)
#
# Cell In[74], line 4, in matrix_coeff_differentials_pos(n)
#       2 matrix_diff = matrix(QQ,Integer(3))
#       3 for i in range(Integer(3)):
# ----> 4     if differential_zn(f,i,n) == Integer(0):
#       5         pol_coef = Integer(0)
#       6     else:
#
# Cell In[73], line 8, in differential_zn(f, i, n)
#       6 if n == Integer(0):
#       7     return i*x**(i-Integer(1))*z**Integer(0)
# ----> 8 return (i*x**(i-Integer(1))*z**n+reduction_deg_2g(f,-Integer(1)/Integer(2)*n*f.derivative(x)*x**i)*z**(n+Integer(2)))
#
# Cell In[70], line 12, in reduction_deg_2g(f, pol)
#      10 n = pol(z=Integer(1)).degree()
#      11 pol += - pol(z=Integer(1)).coefficients()[-Integer(1)]*(f**(floor(n/Integer(3)))-Integer(1)/z**(Integer(2)*floor(n/Integer(3))))*x**(n%Integer(3))
# ---> 12 return reduction_deg_2g(f,pol)
#
# Cell In[70], line 11, in reduction_deg_2g(f, pol)
#       9 else:
#      10     n = pol(z=Integer(1)).degree()
# ---> 11     pol += - pol(z=Integer(1)).coefficients()[-Integer(1)]*(f**(floor(n/Integer(3)))-Integer(1)/z**(Integer(2)*floor(n/Integer(3))))*x**(n%Integer(3))
#      12     return reduction_deg_2g(f,pol)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/integer.pyx:2042, in sage.rings.integer.Integer.__truediv__ (build/cythonized/sage/rings/integer.c:24493)()
#    2040         return y
#    2041
# -> 2042     return coercion_model.bin_op(left, right, operator.truediv)
#    2043
#    2044 cpdef _div_(self, right):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce.pyx:1238, in sage.structure.coerce.CoercionModel.bin_op (build/cythonized/sage/structure/coerce.c:15970)()
#    1236     self._record_exception()
#    1237 else:
# -> 1238     return PyObject_CallObject(op, xy)
#    1239
#    1240 if op is mul:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/element.pyx:1729, in sage.structure.element.Element.__truediv__ (build/cythonized/sage/structure/element.c:21261)()
#    1727 cdef int cl = classify_elements(left, right)
#    1728 if HAVE_SAME_PARENT(cl):
# -> 1729     return (<Element>left)._div_(right)
#    1730 if BOTH_ARE_ELEMENT(cl):
#    1731     return coercion_model.bin_op(left, right, truediv)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/power_series_ring_element.pyx:1094, in sage.rings.power_series_ring_element.PowerSeries._div_ (build/cythonized/sage/rings/power_series_ring_element.c:17590)()
#    1092     except (TypeError, NotImplementedError):  # no integral domain
#    1093         R = self._parent.laurent_series_ring()
# -> 1094     return R(self) / R(denom)
#    1095
#    1096 # Algorithm: Cancel common factors of q from top and bottom,
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12762)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:164, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6979)()
#     162             print(type(C), C)
#     163             print(type(C._element_constructor), C._element_constructor)
# --> 164         raise
#     165
#     166 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:159, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6871)()
#     157 cdef Parent C = self._codomain
#     158 try:
# --> 159     return C._element_constructor(x)
#     160 except Exception:
#     161     if print_warnings:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/laurent_series_ring.py:565, in LaurentSeriesRing._element_constructor_(self, x, n, prec)
#     563     else:
#     564         x = x.add_bigoh(prec)
# --> 565 return self.element_class(self, x, n).add_bigoh(prec)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/laurent_series_ring_element.pyx:154, in sage.rings.laurent_series_ring_element.LaurentSeries.__init__ (build/cythonized/sage/rings/laurent_series_ring_element.c:7217)()
#     152 ## same parent are unique.
#     153 elif parent is not f.parent():
# --> 154     f = parent._power_series_ring(f)
#     155
#     156 # self is that t^n * u:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12762)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:164, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6979)()
#     162             print(type(C), C)
#     163             print(type(C._element_constructor), C._element_constructor)
# --> 164         raise
#     165
#     166 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:159, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6871)()
#     157 cdef Parent C = self._codomain
#     158 try:
# --> 159     return C._element_constructor(x)
#     160 except Exception:
#     161     if print_warnings:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/power_series_ring.py:865, in PowerSeriesRing_generic._element_constructor_(self, f, prec, check)
#     863         else:
#     864             f = f.add_bigoh(prec)
# --> 865 return self.element_class(self, f, prec, check=check)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/power_series_poly.pyx:55, in sage.rings.power_series_poly.PowerSeries_poly.__init__ (build/cythonized/sage/rings/power_series_poly.c:6589)()
#      53 elif isinstance(f, PowerSeries):  # not only PowerSeries_poly
#      54     prec = (<PowerSeries>f)._prec
# ---> 55     f = R(f.polynomial())
#      56 else:
#      57     if f:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12762)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/polynomial/polynomial_ring_homomorphism.pyx:63, in sage.rings.polynomial.polynomial_ring_homomorphism.PolynomialRingHomomorphism_from_base._call_ (build/cythonized/sage/rings/polynomial/polynomial_ring_homomorphism.c:5254)()
#      61         return P({a: f(b) for a, b in x.monomial_coefficients().items()})
#      62     else:
# ---> 63         return P([f(b) for b in x])
#      64
#      65 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/categories/map.pyx:808, in sage.categories.map.Map.__call__ (build/cythonized/sage/categories/map.c:10130)()
#     806 if P is D:  # we certainly want to call _call_/with_args
#     807     if not args and not kwds:
# --> 808         return self._call_(x)
#     809     return self._call_with_args(x, args, kwds)
#     810 # Is there coercion?
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:164, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6979)()
#     162             print(type(C), C)
#     163             print(type(C._element_constructor), C._element_constructor)
# --> 164         raise
#     165
#     166 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:159, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6871)()
#     157 cdef Parent C = self._codomain
#     158 try:
# --> 159     return C._element_constructor(x)
#     160 except Exception:
#     161     if print_warnings:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/laurent_series_ring.py:565, in LaurentSeriesRing._element_constructor_(self, x, n, prec)
#     563     else:
#     564         x = x.add_bigoh(prec)
# --> 565 return self.element_class(self, x, n).add_bigoh(prec)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/laurent_series_ring_element.pyx:154, in sage.rings.laurent_series_ring_element.LaurentSeries.__init__ (build/cythonized/sage/rings/laurent_series_ring_element.c:7217)()
#     152 ## same parent are unique.
#     153 elif parent is not f.parent():
# --> 154     f = parent._power_series_ring(f)
#     155
#     156 # self is that t^n * u:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12762)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:164, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6979)()
#     162             print(type(C), C)
#     163             print(type(C._element_constructor), C._element_constructor)
# --> 164         raise
#     165
#     166 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:159, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6871)()
#     157 cdef Parent C = self._codomain
#     158 try:
# --> 159     return C._element_constructor(x)
#     160 except Exception:
#     161     if print_warnings:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/power_series_ring.py:865, in PowerSeriesRing_generic._element_constructor_(self, f, prec, check)
#     863         else:
#     864             f = f.add_bigoh(prec)
# --> 865 return self.element_class(self, f, prec, check=check)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/power_series_poly.pyx:55, in sage.rings.power_series_poly.PowerSeries_poly.__init__ (build/cythonized/sage/rings/power_series_poly.c:6589)()
#      53 elif isinstance(f, PowerSeries):  # not only PowerSeries_poly
#      54     prec = (<PowerSeries>f)._prec
# ---> 55     f = R(f.polynomial())
#      56 else:
#      57     if f:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12762)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/polynomial/polynomial_ring_homomorphism.pyx:63, in sage.rings.polynomial.polynomial_ring_homomorphism.PolynomialRingHomomorphism_from_base._call_ (build/cythonized/sage/rings/polynomial/polynomial_ring_homomorphism.c:5289)()
#      61         return P({a: f(b) for a, b in x.monomial_coefficients().items()})
#      62     else:
# ---> 63         return P([f(b) for b in x])
#      64
#      65 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12762)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:164, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6979)()
#     162             print(type(C), C)
#     163             print(type(C._element_constructor), C._element_constructor)
# --> 164         raise
#     165
#     166 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:159, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6871)()
#     157 cdef Parent C = self._codomain
#     158 try:
# --> 159     return C._element_constructor(x)
#     160 except Exception:
#     161     if print_warnings:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/polynomial/polynomial_ring.py:445, in PolynomialRing_general._element_constructor_(self, x, check, is_gen, construct, **kwds)
#     443 C = self.element_class
#     444 if isinstance(x, (list, tuple)):
# --> 445     return C(self, x, check=check, is_gen=False, construct=construct)
#     446 if isinstance(x, range):
#     447     return C(self, list(x), check=check, is_gen=False,
#     448              construct=construct)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/polynomial/padics/polynomial_padic_capped_relative_dense.py:157, in Polynomial_padic_capped_relative_dense.__init__(self, parent, x, check, is_gen, construct, absprec, relprec)
#     155 self._valaddeds = [c - self._valbase for c in self._valaddeds]
#     156 self._relprecs = [a.precision_absolute() - self._valbase for a in x]
# --> 157 self._poly = PolynomialRing(ZZ, parent.variable_name())([a >> self._valbase for a in x])
#     158 self._normalized = True
#     159 if absprec is not infinity or relprec is not infinity:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/polynomial/polynomial_ring_constructor.py:722, in PolynomialRing(base_ring, *args, **kwds)
#     720     return _multi_variate(base_ring, names, **kwds)
#     721 else:
# --> 722     return _single_variate(base_ring, names, **kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/polynomial/polynomial_ring_constructor.py:757, in _single_variate(base_ring, name, sparse, implementation, order)
#     755 # "implementation" must be last
#     756 key = [base_ring, name, sparse, implementation]
# --> 757 R = _get_from_cache(key)
#     758 if R is not None:
#     759     return R
#
# RecursionError: maximum recursion depth exceeded

# %%
M
# Out:
# [2*5 + 2*5^3 + 3*5^4 + 4*5^6 + 2*5^7 + 3*5^8 + 3*5^9 + O(5^10)                                                       O(5^10)]
# [                                                      O(5^10)  3 + 2*5 + 4*5^2 + 2*5^3 + 5^4 + 4*5^5 + 2*5^7 + 5^8 + O(5^9)]

# %%
M.characteristic_polynomial()
# Out:
# (1 + O(5^10))*x^2 + (2 + O(5^9))*x + 5 + O(5^10)

# %%
frob_omega = p*x^(p-1)*frob_z
frob_eta = p*x^(2*p-1)*frob_z

red_frob_eta = reduction_coeff(frob_eta)
red_frob_omega = reduction_coeff(frob_omega)

# %%
reduction_z_pos(red_frob_eta)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 reduction_z_pos(red_frob_eta)
#
# Cell In[76], line 10, in reduction_z_pos(pow_ser, exact_form)
#       8 X = M.solve_right(V)
#       9 exact_form += X.dot_product(vector([x**Integer(0)*z**(k-Integer(2)),x**Integer(1)*z**(k-Integer(2)),x**Integer(2)*z**(k-Integer(2))]))
# ---> 10 return reduction_z_pos(pow_ser-X.dot_product(vector([differential_zn(f,Integer(0),k-Integer(2)),differential_zn(f,Integer(1),k-Integer(2)),differential_zn(f,Integer(2),k-Integer(2))])),exact_form)
#
# Cell In[76], line 10, in reduction_z_pos(pow_ser, exact_form)
#       8 X = M.solve_right(V)
#       9 exact_form += X.dot_product(vector([x**Integer(0)*z**(k-Integer(2)),x**Integer(1)*z**(k-Integer(2)),x**Integer(2)*z**(k-Integer(2))]))
# ---> 10 return reduction_z_pos(pow_ser-X.dot_product(vector([differential_zn(f,Integer(0),k-Integer(2)),differential_zn(f,Integer(1),k-Integer(2)),differential_zn(f,Integer(2),k-Integer(2))])),exact_form)
#
#     [... skipping similar frames: reduction_z_pos at line 10 (2961 times)]
#
# Cell In[76], line 10, in reduction_z_pos(pow_ser, exact_form)
#       8 X = M.solve_right(V)
#       9 exact_form += X.dot_product(vector([x**Integer(0)*z**(k-Integer(2)),x**Integer(1)*z**(k-Integer(2)),x**Integer(2)*z**(k-Integer(2))]))
# ---> 10 return reduction_z_pos(pow_ser-X.dot_product(vector([differential_zn(f,Integer(0),k-Integer(2)),differential_zn(f,Integer(1),k-Integer(2)),differential_zn(f,Integer(2),k-Integer(2))])),exact_form)
#
# Cell In[76], line 6, in reduction_z_pos(pow_ser, exact_form)
#       4 else:
#       5     k = pow_ser.degree()
# ----> 6     M = matrix_coeff_differentials_pos(k-Integer(2))
#       7     V = vector_coeff(pow_ser.coefficients()[-Integer(1)])
#       8     X = M.solve_right(V)
#
# Cell In[74], line 4, in matrix_coeff_differentials_pos(n)
#       2 matrix_diff = matrix(QQ,Integer(3))
#       3 for i in range(Integer(3)):
# ----> 4     if differential_zn(f,i,n) == Integer(0):
#       5         pol_coef = Integer(0)
#       6     else:
#
# Cell In[73], line 8, in differential_zn(f, i, n)
#       6 if n == Integer(0):
#       7     return i*x**(i-Integer(1))*z**Integer(0)
# ----> 8 return (i*x**(i-Integer(1))*z**n+reduction_deg_2g(f,-Integer(1)/Integer(2)*n*f.derivative(x)*x**i)*z**(n+Integer(2)))
#
# Cell In[70], line 12, in reduction_deg_2g(f, pol)
#      10 n = pol(z=Integer(1)).degree()
#      11 pol += - pol(z=Integer(1)).coefficients()[-Integer(1)]*(f**(floor(n/Integer(3)))-Integer(1)/z**(Integer(2)*floor(n/Integer(3))))*x**(n%Integer(3))
# ---> 12 return reduction_deg_2g(f,pol)
#
# Cell In[70], line 11, in reduction_deg_2g(f, pol)
#       9 else:
#      10     n = pol(z=Integer(1)).degree()
# ---> 11     pol += - pol(z=Integer(1)).coefficients()[-Integer(1)]*(f**(floor(n/Integer(3)))-Integer(1)/z**(Integer(2)*floor(n/Integer(3))))*x**(n%Integer(3))
#      12     return reduction_deg_2g(f,pol)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/integer.pyx:2042, in sage.rings.integer.Integer.__truediv__ (build/cythonized/sage/rings/integer.c:24493)()
#    2040         return y
#    2041
# -> 2042     return coercion_model.bin_op(left, right, operator.truediv)
#    2043
#    2044 cpdef _div_(self, right):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce.pyx:1238, in sage.structure.coerce.CoercionModel.bin_op (build/cythonized/sage/structure/coerce.c:15970)()
#    1236     self._record_exception()
#    1237 else:
# -> 1238     return PyObject_CallObject(op, xy)
#    1239
#    1240 if op is mul:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/element.pyx:1729, in sage.structure.element.Element.__truediv__ (build/cythonized/sage/structure/element.c:21261)()
#    1727 cdef int cl = classify_elements(left, right)
#    1728 if HAVE_SAME_PARENT(cl):
# -> 1729     return (<Element>left)._div_(right)
#    1730 if BOTH_ARE_ELEMENT(cl):
#    1731     return coercion_model.bin_op(left, right, truediv)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/power_series_ring_element.pyx:1094, in sage.rings.power_series_ring_element.PowerSeries._div_ (build/cythonized/sage/rings/power_series_ring_element.c:17590)()
#    1092     except (TypeError, NotImplementedError):  # no integral domain
#    1093         R = self._parent.laurent_series_ring()
# -> 1094     return R(self) / R(denom)
#    1095
#    1096 # Algorithm: Cancel common factors of q from top and bottom,
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12762)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:164, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6979)()
#     162             print(type(C), C)
#     163             print(type(C._element_constructor), C._element_constructor)
# --> 164         raise
#     165
#     166 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:159, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6871)()
#     157 cdef Parent C = self._codomain
#     158 try:
# --> 159     return C._element_constructor(x)
#     160 except Exception:
#     161     if print_warnings:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/laurent_series_ring.py:565, in LaurentSeriesRing._element_constructor_(self, x, n, prec)
#     563     else:
#     564         x = x.add_bigoh(prec)
# --> 565 return self.element_class(self, x, n).add_bigoh(prec)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/laurent_series_ring_element.pyx:154, in sage.rings.laurent_series_ring_element.LaurentSeries.__init__ (build/cythonized/sage/rings/laurent_series_ring_element.c:7217)()
#     152 ## same parent are unique.
#     153 elif parent is not f.parent():
# --> 154     f = parent._power_series_ring(f)
#     155
#     156 # self is that t^n * u:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12762)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:164, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6979)()
#     162             print(type(C), C)
#     163             print(type(C._element_constructor), C._element_constructor)
# --> 164         raise
#     165
#     166 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:159, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6871)()
#     157 cdef Parent C = self._codomain
#     158 try:
# --> 159     return C._element_constructor(x)
#     160 except Exception:
#     161     if print_warnings:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/power_series_ring.py:865, in PowerSeriesRing_generic._element_constructor_(self, f, prec, check)
#     863         else:
#     864             f = f.add_bigoh(prec)
# --> 865 return self.element_class(self, f, prec, check=check)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/power_series_poly.pyx:55, in sage.rings.power_series_poly.PowerSeries_poly.__init__ (build/cythonized/sage/rings/power_series_poly.c:6589)()
#      53 elif isinstance(f, PowerSeries):  # not only PowerSeries_poly
#      54     prec = (<PowerSeries>f)._prec
# ---> 55     f = R(f.polynomial())
#      56 else:
#      57     if f:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12762)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/polynomial/polynomial_ring_homomorphism.pyx:63, in sage.rings.polynomial.polynomial_ring_homomorphism.PolynomialRingHomomorphism_from_base._call_ (build/cythonized/sage/rings/polynomial/polynomial_ring_homomorphism.c:5254)()
#      61         return P({a: f(b) for a, b in x.monomial_coefficients().items()})
#      62     else:
# ---> 63         return P([f(b) for b in x])
#      64
#      65 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/categories/map.pyx:808, in sage.categories.map.Map.__call__ (build/cythonized/sage/categories/map.c:10130)()
#     806 if P is D:  # we certainly want to call _call_/with_args
#     807     if not args and not kwds:
# --> 808         return self._call_(x)
#     809     return self._call_with_args(x, args, kwds)
#     810 # Is there coercion?
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:164, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6979)()
#     162             print(type(C), C)
#     163             print(type(C._element_constructor), C._element_constructor)
# --> 164         raise
#     165
#     166 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:159, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6871)()
#     157 cdef Parent C = self._codomain
#     158 try:
# --> 159     return C._element_constructor(x)
#     160 except Exception:
#     161     if print_warnings:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/laurent_series_ring.py:565, in LaurentSeriesRing._element_constructor_(self, x, n, prec)
#     563     else:
#     564         x = x.add_bigoh(prec)
# --> 565 return self.element_class(self, x, n).add_bigoh(prec)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/laurent_series_ring_element.pyx:154, in sage.rings.laurent_series_ring_element.LaurentSeries.__init__ (build/cythonized/sage/rings/laurent_series_ring_element.c:7217)()
#     152 ## same parent are unique.
#     153 elif parent is not f.parent():
# --> 154     f = parent._power_series_ring(f)
#     155
#     156 # self is that t^n * u:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12762)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:164, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6979)()
#     162             print(type(C), C)
#     163             print(type(C._element_constructor), C._element_constructor)
# --> 164         raise
#     165
#     166 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:159, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6871)()
#     157 cdef Parent C = self._codomain
#     158 try:
# --> 159     return C._element_constructor(x)
#     160 except Exception:
#     161     if print_warnings:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/power_series_ring.py:865, in PowerSeriesRing_generic._element_constructor_(self, f, prec, check)
#     863         else:
#     864             f = f.add_bigoh(prec)
# --> 865 return self.element_class(self, f, prec, check=check)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/power_series_poly.pyx:55, in sage.rings.power_series_poly.PowerSeries_poly.__init__ (build/cythonized/sage/rings/power_series_poly.c:6589)()
#      53 elif isinstance(f, PowerSeries):  # not only PowerSeries_poly
#      54     prec = (<PowerSeries>f)._prec
# ---> 55     f = R(f.polynomial())
#      56 else:
#      57     if f:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12762)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/polynomial/polynomial_ring_homomorphism.pyx:63, in sage.rings.polynomial.polynomial_ring_homomorphism.PolynomialRingHomomorphism_from_base._call_ (build/cythonized/sage/rings/polynomial/polynomial_ring_homomorphism.c:5289)()
#      61         return P({a: f(b) for a, b in x.monomial_coefficients().items()})
#      62     else:
# ---> 63         return P([f(b) for b in x])
#      64
#      65 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/parent.pyx:901, in sage.structure.parent.Parent.__call__ (build/cythonized/sage/structure/parent.c:12762)()
#     899 if mor is not None:
#     900     if no_extra_args:
# --> 901         return mor._call_(x)
#     902     else:
#     903         return mor._call_with_args(x, args, kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:164, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6979)()
#     162             print(type(C), C)
#     163             print(type(C._element_constructor), C._element_constructor)
# --> 164         raise
#     165
#     166 cpdef Element _call_with_args(self, x, args=(), kwds={}):
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/structure/coerce_maps.pyx:159, in sage.structure.coerce_maps.DefaultConvertMap_unique._call_ (build/cythonized/sage/structure/coerce_maps.c:6871)()
#     157 cdef Parent C = self._codomain
#     158 try:
# --> 159     return C._element_constructor(x)
#     160 except Exception:
#     161     if print_warnings:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/polynomial/polynomial_ring.py:445, in PolynomialRing_general._element_constructor_(self, x, check, is_gen, construct, **kwds)
#     443 C = self.element_class
#     444 if isinstance(x, (list, tuple)):
# --> 445     return C(self, x, check=check, is_gen=False, construct=construct)
#     446 if isinstance(x, range):
#     447     return C(self, list(x), check=check, is_gen=False,
#     448              construct=construct)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/polynomial/padics/polynomial_padic_capped_relative_dense.py:157, in Polynomial_padic_capped_relative_dense.__init__(self, parent, x, check, is_gen, construct, absprec, relprec)
#     155 self._valaddeds = [c - self._valbase for c in self._valaddeds]
#     156 self._relprecs = [a.precision_absolute() - self._valbase for a in x]
# --> 157 self._poly = PolynomialRing(ZZ, parent.variable_name())([a >> self._valbase for a in x])
#     158 self._normalized = True
#     159 if absprec is not infinity or relprec is not infinity:
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/polynomial/polynomial_ring_constructor.py:722, in PolynomialRing(base_ring, *args, **kwds)
#     720     return _multi_variate(base_ring, names, **kwds)
#     721 else:
# --> 722     return _single_variate(base_ring, names, **kwds)
#
# File /private/var/tmp/sage-10.5-current/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/sage/rings/polynomial/polynomial_ring_constructor.py:757, in _single_variate(base_ring, name, sparse, implementation, order)
#     755 # "implementation" must be last
#     756 key = [base_ring, name, sparse, implementation]
# --> 757 R = _get_from_cache(key)
#     758 if R is not None:
#     759     return R
#
# RecursionError: maximum recursion depth exceeded
